# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.4 LTS
# Release:	22.04
# Codename:	jammy

# %%
# https://learn.microsoft.com/en-us/dotnet/core/install/linux-ubuntu-install?tabs=dotnet9&pivots=os-linux-ubuntu-2204
# !sudo add-apt-repository -y ppa:dotnet/backports
# !sudo apt-get update && \
  sudo apt-get install -y dotnet-sdk-9.0
# Out:
# PPA publishes dbgsym, you may need to include 'main/debug' component
# Repository: 'deb https://ppa.launchpadcontent.net/dotnet/backports/ubuntu/ jammy main'
# Description:
# The backports archive provides source-built .NET packages in cases where a version of .NET is not available in the archive for an Ubuntu release.
#
# Currently available Ubuntu releases and .NET backports:
#
# Ubuntu 24.04 LTS (Noble Numbat)
# ├── .NET 6.0 (End of Life on November 12th, 2024) [amd64 arm64]
# ├── .NET 7.0 (End of Life on May 14th, 2024)      [amd64 arm64]
# └── .NET 9.0 (End of Life on May 11th, 2026)      [amd64 arm64 s390x ppc64el]
#
# Ubuntu 22.04 LTS (Jammy Jellyfish)
# └── .NET 9.0 (End of Life on May 11th, 2026)      [amd64 arm64 s390x ppc64el]
#
# Canonical provides best-effort support for packages contained in this archive, which is limited to the upstream lifespan or the support period of the particular Ubuntu version. See the upstream support policy [1] for more information about the upstream support lifespan of .NET releases or the Ubuntu Releases Wiki entry [2] for more information about the support period of any Ubuntu version.
#
# Any build enters ppa:dotnet/backports-proposed [3] first and migrates to this archive if no regressions are reported within a week.
#
# [1] https://dotnet.microsoft.com/en-us/platform/support/policy/dotnet-core
# [2] https://wiki.ubuntu.com/Releases
# [3] https://launchpad.net/~dotnet/+archive/ubuntu/backports-proposed
# More info: https://launchpad.net/~dotnet/+archive/ubuntu/backports
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/dotnet-ubuntu-backports-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/dotnet-ubuntu-backports-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/dotnet-ubuntu-backports.gpg with fingerprint 45A3F127159BE9E5017811C62125B164E8E5D3FA
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,607 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy InRelease [24.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,863 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,701 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:16 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 Packages [3,119 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,154 kB]
# Get:18 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.4 kB]
# Fetched 18.4 MB in 4s (4,446 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:9 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aspnetcore-runtime-9.0 aspnetcore-targeting-pack-9.0 dotnet-apphost-pack-9.0
#   dotnet-host-9.0 dotnet-hostfxr-9.0 dotnet-runtime-9.0 dotnet-sdk-aot-9.0
#   dotnet-targeting-pack-9.0 dotnet-templates-9.0 liblttng-ust-common1
#   liblttng-ust-ctl5 liblttng-ust1 netstandard-targeting-pack-2.1-9.0
# Suggested packages:
#   aspnetcore-runtime-dbg-9.0 dotnet-runtime-dbg-9.0 dotnet-sdk-dbg-9.0
# The following NEW packages will be installed:
#   aspnetcore-runtime-9.0 aspnetcore-targeting-pack-9.0 dotnet-apphost-pack-9.0
#   dotnet-host-9.0 dotnet-hostfxr-9.0 dotnet-runtime-9.0 dotnet-sdk-9.0
#   dotnet-sdk-aot-9.0 dotnet-targeting-pack-9.0 dotnet-templates-9.0
#   liblttng-ust-common1 liblttng-ust-ctl5 liblttng-ust1
#   netstandard-targeting-pack-2.1-9.0
# 0 upgraded, 14 newly installed, 0 to remove and 35 not upgraded.
# Need to get 149 MB of archives.
# After this operation, 558 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblttng-ust-common1 amd64 2.13.1-1ubuntu1 [27.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblttng-ust-ctl5 amd64 2.13.1-1ubuntu1 [77.9 kB]
# Get:3 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-host-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [205 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblttng-ust1 amd64 2.13.1-1ubuntu1 [190 kB]
# Get:5 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-hostfxr-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [153 kB]
# Get:6 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-runtime-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [25.1 MB]
# Get:7 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 aspnetcore-runtime-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [8,274 kB]
# Get:8 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 aspnetcore-targeting-pack-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [1,955 kB]
# Get:9 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-apphost-pack-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [3,668 kB]
# Get:10 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-targeting-pack-9.0 amd64 9.0.4-0ubuntu1~22.04.1~ppa1 [3,127 kB]
# Get:11 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-templates-9.0 amd64 9.0.105-0ubuntu1~22.04.1~ppa1 [2,715 kB]
# Get:12 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 netstandard-targeting-pack-2.1-9.0 amd64 9.0.105-0ubuntu1~22.04.1~ppa1 [1,409 kB]
# Get:13 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-sdk-9.0 amd64 9.0.105-0ubuntu1~22.04.1~ppa1 [86.0 MB]
# Get:14 https://ppa.launchpadcontent.net/dotnet/backports/ubuntu jammy/main amd64 dotnet-sdk-aot-9.0 amd64 9.0.105-0ubuntu1~22.04.1~ppa1 [16.0 MB]
# Fetched 149 MB in 9s (16.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 14.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dotnet-host-9.0.
# (Reading database ... 126333 files and directories currently installed.)
# Preparing to unpack .../00-dotnet-host-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-host-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package dotnet-hostfxr-9.0.
# Preparing to unpack .../01-dotnet-hostfxr-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-hostfxr-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package liblttng-ust-common1:amd64.
# Preparing to unpack .../02-liblttng-ust-common1_2.13.1-1ubuntu1_amd64.deb ...
# Unpacking liblttng-ust-common1:amd64 (2.13.1-1ubuntu1) ...
# Selecting previously unselected package liblttng-ust-ctl5:amd64.
# Preparing to unpack .../03-liblttng-ust-ctl5_2.13.1-1ubuntu1_amd64.deb ...
# Unpacking liblttng-ust-ctl5:amd64 (2.13.1-1ubuntu1) ...
# Selecting previously unselected package liblttng-ust1:amd64.
# Preparing to unpack .../04-liblttng-ust1_2.13.1-1ubuntu1_amd64.deb ...
# Unpacking liblttng-ust1:amd64 (2.13.1-1ubuntu1) ...
# Selecting previously unselected package dotnet-runtime-9.0.
# Preparing to unpack .../05-dotnet-runtime-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-runtime-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package aspnetcore-runtime-9.0.
# Preparing to unpack .../06-aspnetcore-runtime-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking aspnetcore-runtime-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package aspnetcore-targeting-pack-9.0.
# Preparing to unpack .../07-aspnetcore-targeting-pack-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking aspnetcore-targeting-pack-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package dotnet-apphost-pack-9.0.
# Preparing to unpack .../08-dotnet-apphost-pack-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-apphost-pack-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package dotnet-targeting-pack-9.0.
# Preparing to unpack .../09-dotnet-targeting-pack-9.0_9.0.4-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-targeting-pack-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package dotnet-templates-9.0.
# Preparing to unpack .../10-dotnet-templates-9.0_9.0.105-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-templates-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package netstandard-targeting-pack-2.1-9.0.
# Preparing to unpack .../11-netstandard-targeting-pack-2.1-9.0_9.0.105-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking netstandard-targeting-pack-2.1-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package dotnet-sdk-9.0.
# Preparing to unpack .../12-dotnet-sdk-9.0_9.0.105-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-sdk-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Selecting previously unselected package dotnet-sdk-aot-9.0.
# Preparing to unpack .../13-dotnet-sdk-aot-9.0_9.0.105-0ubuntu1~22.04.1~ppa1_amd64.deb ...
# Unpacking dotnet-sdk-aot-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Setting up liblttng-ust-common1:amd64 (2.13.1-1ubuntu1) ...
# Setting up dotnet-targeting-pack-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up liblttng-ust-ctl5:amd64 (2.13.1-1ubuntu1) ...
# Setting up dotnet-apphost-pack-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up aspnetcore-targeting-pack-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up liblttng-ust1:amd64 (2.13.1-1ubuntu1) ...
# Setting up dotnet-host-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up netstandard-targeting-pack-2.1-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Setting up dotnet-hostfxr-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up dotnet-templates-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Setting up dotnet-runtime-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up aspnetcore-runtime-9.0 (9.0.4-0ubuntu1~22.04.1~ppa1) ...
# Setting up dotnet-sdk-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Setting up dotnet-sdk-aot-9.0 (9.0.105-0ubuntu1~22.04.1~ppa1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
# !dotnet --version

# %%
# !dotnet --list-sdks
# Out:
# 9.0.105 [/usr/lib/dotnet/sdk]

# %%
# !dotnet --info
